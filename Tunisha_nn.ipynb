# %% [markdown]
# ###Problem statement:
# Build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %%
#import the libraries
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
from tensorflow.keras.models import Sequential

# %%
#dataset is saved in a gdrive so mount the drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/CNN/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/CNN/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ###Load using keras.preprocessing
# Let's load these images off disk using the helpful image_dataset_from_directory utility.
#
# ###Create a dataset
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'training',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split= 0.2,
    subset= 'validation',
    image_size=(img_height,img_width),
    batch_size = batch_size
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ###Visualize the data<br>
# Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(9): 
  plt.subplot(3, 3, i + 1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The image_batch is a tensor of the shape (32, 180, 180, 3). This is a batch of 32 images of shape 180x180x3 (the last dimension refers to color channels RGB). The label_batch is a tensor of the shape (32,), these are corresponding labels to the 32 images.

# %% [markdown]
# ###visulaize the distribution of classes in training data

# %%
def class_distribution_count(directory):
    
    #count number of image in each classes
    count= []
    for path in pathlib.Path(directory).iterdir():
        if path.is_dir():
            count.append(len([name for name in os.listdir(path)
                               if os.path.isfile(os.path.join(path, name))]))
    
    #name of the classes
    sub_directory = [name for name in os.listdir(directory)
                    if os.path.isdir(os.path.join(directory, name))]
    
    #return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution_count(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0  pigmented benign keratosis           462
# 1           actinic keratosis           114
# 2              dermatofibroma            95
# 3        seborrheic keratosis            77
# 4                    melanoma           438
# 5             vascular lesion           139
# 6        basal cell carcinoma           376
# 7     squamous cell carcinoma           181
# 8                       nevus           357

# %%
#Visualize the Number of image in each class.
import seaborn as sns
plt.figure(figsize=(10, 8))
sns.barplot(x="No. of Image", y="Class", data=df,
            label="Class")

# %% [markdown]
# There is a class imbalance to solve this using a python package Augmentor.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ###Create the model
# Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
### Your code goes here
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# ###Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 32)      2432
#
#  conv2d_1 (Conv2D)           (None, 180, 180, 32)      25632
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 90, 90, 32)        25632
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 45, 45, 64)        51264
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 22, 22, 64)        102464
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 11, 11, 64)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense (Dense)               (None, 9)                 69705
#
# =================================================================
# Total params: 277,129
# Trainable params: 277,129
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 187s 698ms/step - loss: 2.0515 - accuracy: 0.1987 - val_loss: 2.0312 - val_accuracy: 0.1499
# Epoch 2/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0268 - accuracy: 0.1987 - val_loss: 2.0285 - val_accuracy: 0.2058
# Epoch 3/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0433 - accuracy: 0.1970 - val_loss: 2.0504 - val_accuracy: 0.1924
# Epoch 4/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0202 - accuracy: 0.2042 - val_loss: 2.0326 - val_accuracy: 0.2058
# Epoch 5/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0373 - accuracy: 0.1914 - val_loss: 2.0252 - val_accuracy: 0.2058
# Epoch 6/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0218 - accuracy: 0.1881 - val_loss: 2.0439 - val_accuracy: 0.2058
# Epoch 7/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0245 - accuracy: 0.2087 - val_loss: 2.0725 - val_accuracy: 0.2103
# Epoch 8/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0122 - accuracy: 0.1830 - val_loss: 2.1142 - val_accuracy: 0.1857
# Epoch 9/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0121 - accuracy: 0.2065 - val_loss: 2.0440 - val_accuracy: 0.2081
# Epoch 10/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0076 - accuracy: 0.2054 - val_loss: 2.0972 - val_accuracy: 0.2058
# Epoch 11/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0002 - accuracy: 0.2009 - val_loss: 2.0606 - val_accuracy: 0.2058
# Epoch 12/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0001 - accuracy: 0.2210 - val_loss: 2.0750 - val_accuracy: 0.1924
# Epoch 13/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9830 - accuracy: 0.2215 - val_loss: 2.0323 - val_accuracy: 0.2058
# Epoch 14/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0248 - accuracy: 0.2210 - val_loss: 2.0674 - val_accuracy: 0.2058
# Epoch 15/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0217 - accuracy: 0.2221 - val_loss: 2.1892 - val_accuracy: 0.1879
# Epoch 16/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9871 - accuracy: 0.2199 - val_loss: 2.1745 - val_accuracy: 0.1902
# Epoch 17/30
# 56/56 [==============================] - 4s 76ms/step - loss: 2.0042 - accuracy: 0.1987 - val_loss: 2.1168 - val_accuracy: 0.2058
# Epoch 18/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9867 - accuracy: 0.2215 - val_loss: 2.1461 - val_accuracy: 0.1924
# Epoch 19/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9819 - accuracy: 0.2093 - val_loss: 2.1407 - val_accuracy: 0.2013
# Epoch 20/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9719 - accuracy: 0.2232 - val_loss: 2.1244 - val_accuracy: 0.2081
# Epoch 21/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9362 - accuracy: 0.2427 - val_loss: 2.1559 - val_accuracy: 0.2237
# Epoch 22/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9015 - accuracy: 0.2606 - val_loss: 2.1945 - val_accuracy: 0.1879
# Epoch 23/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9836 - accuracy: 0.2121 - val_loss: 2.1717 - val_accuracy: 0.2058
# Epoch 24/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9565 - accuracy: 0.2260 - val_loss: 2.1754 - val_accuracy: 0.2058
# Epoch 25/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.9478 - accuracy: 0.2383 - val_loss: 2.1843 - val_accuracy: 0.2125
# Epoch 26/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9339 - accuracy: 0.2360 - val_loss: 2.1618 - val_accuracy: 0.2483
# Epoch 27/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.9260 - accuracy: 0.2606 - val_loss: 2.0663 - val_accuracy: 0.2506
# Epoch 28/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.8785 - accuracy: 0.2896 - val_loss: 2.1726 - val_accuracy: 0.2595
# Epoch 29/30
# 56/56 [==============================] - 4s 77ms/step - loss: 1.8756 - accuracy: 0.2779 - val_loss: 2.0938 - val_accuracy: 0.2662
# Epoch 30/30
# 56/56 [==============================] - 4s 76ms/step - loss: 1.8430 - accuracy: 0.3030 - val_loss: 2.0936 - val_accuracy: 0.2506

# %% [markdown]
# ###Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ###Finding on the first base model
#
# The model is overfitting because we can also see difference in loss functions in training & test around the 10-11th epoch
#
# The accuracy is just around 75-80% because there are enough features to remember the pattern.
#
# But again, it's too early to comment on the overfitting & underfitting debate

# %%
#Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 
data_augument = keras.Sequential([
                             layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical",input_shape=(img_height,img_width,3)),
                             layers.experimental.preprocessing.RandomRotation(0.2, fill_mode='reflect'),
                             layers.experimental.preprocessing.RandomZoom(height_factor=(0.2, 0.3), width_factor=(0.2, 0.3), fill_mode='reflect')
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(12, 12))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(data_augument(images)[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# Create the model, compile and train the model

# %%
# You can use Dropout layer if there is an evidence of overfitting in your findings
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
num_classes = 9
model = Sequential([ data_augument,
                    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width,3))
      
])
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (180, 180, 32)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))


model.add(Flatten())
model.add(Dense(num_classes, activation = "softmax"))

# %% [markdown]
# compiling the model

# %%
### Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
## Your code goes here, note: train your model for 20 epochs
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 56/56 [==============================] - 7s 91ms/step - loss: 2.0574 - accuracy: 0.1836 - val_loss: 2.0043 - val_accuracy: 0.2327
# Epoch 2/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0285 - accuracy: 0.2282 - val_loss: 1.9668 - val_accuracy: 0.2707
# Epoch 3/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.9628 - accuracy: 0.2578 - val_loss: 1.9395 - val_accuracy: 0.2528
# Epoch 4/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.9469 - accuracy: 0.2372 - val_loss: 1.9498 - val_accuracy: 0.2483
# Epoch 5/30
# 56/56 [==============================] - 5s 86ms/step - loss: 1.9029 - accuracy: 0.2874 - val_loss: 1.9275 - val_accuracy: 0.2617
# Epoch 6/30
# 56/56 [==============================] - 5s 89ms/step - loss: 1.9173 - accuracy: 0.2617 - val_loss: 2.0712 - val_accuracy: 0.1544
# Epoch 7/30
# 56/56 [==============================] - 5s 88ms/step - loss: 2.0319 - accuracy: 0.2009 - val_loss: 2.0325 - val_accuracy: 0.1924
# Epoch 8/30
# 56/56 [==============================] - 5s 87ms/step - loss: 2.0249 - accuracy: 0.2048 - val_loss: 2.0470 - val_accuracy: 0.2036
# Epoch 9/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0182 - accuracy: 0.2009 - val_loss: 2.0384 - val_accuracy: 0.1902
# Epoch 10/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.1177 - accuracy: 0.1936 - val_loss: 2.0295 - val_accuracy: 0.1902
# Epoch 11/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0223 - accuracy: 0.1875 - val_loss: 2.0139 - val_accuracy: 0.2125
# Epoch 12/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.1047 - accuracy: 0.2104 - val_loss: 2.0324 - val_accuracy: 0.1924
# Epoch 13/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0189 - accuracy: 0.2054 - val_loss: 2.0284 - val_accuracy: 0.2058
# Epoch 14/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0172 - accuracy: 0.1970 - val_loss: 2.0301 - val_accuracy: 0.1924
# Epoch 15/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0150 - accuracy: 0.2093 - val_loss: 2.0342 - val_accuracy: 0.2081
# Epoch 16/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0184 - accuracy: 0.2070 - val_loss: 2.0260 - val_accuracy: 0.2058
# Epoch 17/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0151 - accuracy: 0.2087 - val_loss: 2.0377 - val_accuracy: 0.1879
# Epoch 18/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0147 - accuracy: 0.2031 - val_loss: 2.0257 - val_accuracy: 0.1902
# Epoch 19/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0159 - accuracy: 0.2026 - val_loss: 2.0314 - val_accuracy: 0.2058
# Epoch 20/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0137 - accuracy: 0.2037 - val_loss: 2.0313 - val_accuracy: 0.2058
# Epoch 21/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0142 - accuracy: 0.2087 - val_loss: 2.0449 - val_accuracy: 0.2081
# Epoch 22/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0181 - accuracy: 0.1970 - val_loss: 2.0354 - val_accuracy: 0.1969
# Epoch 23/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0124 - accuracy: 0.2098 - val_loss: 2.0469 - val_accuracy: 0.2103
# Epoch 24/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0113 - accuracy: 0.2020 - val_loss: 2.0306 - val_accuracy: 0.1902
# Epoch 25/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0134 - accuracy: 0.2015 - val_loss: 2.0301 - val_accuracy: 0.1924
# Epoch 26/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0124 - accuracy: 0.2115 - val_loss: 2.0251 - val_accuracy: 0.2103
# Epoch 27/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0101 - accuracy: 0.2098 - val_loss: 2.0305 - val_accuracy: 0.2103
# Epoch 28/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0341 - accuracy: 0.1987 - val_loss: 2.0222 - val_accuracy: 0.1924
# Epoch 29/30
# 56/56 [==============================] - 5s 86ms/step - loss: 2.0171 - accuracy: 0.2037 - val_loss: 2.0194 - val_accuracy: 0.1902
# Epoch 30/30
# 56/56 [==============================] - 5s 85ms/step - loss: 2.0146 - accuracy: 0.2048 - val_loss: 2.0222 - val_accuracy: 0.2058

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ###Finding from Second Model
#
# There is no improvement in accuracy but we can definitely see the overfitting problem has solved due to data augmentation
#
# We can increase the epochs to increase the accuracy so it's too early for judgement

# %% [markdown]
# previously we have seen that there is a class imbalance so for comfirming this lets find the distribution on training set.

# %%
##
path_list=[]
lesion_list=[]
for i in class_names:
      
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        lesion_list.append(i)
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 1     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 2     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 3     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 4     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2235  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2236  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2237  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2238  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 1     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 2     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 3     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# 4     /content/gdrive/MyDrive/CNN/Train/actinic kera...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2235  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2236  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2237  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
# 2238  /content/gdrive/MyDrive/CNN/Train/vascular les...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
count=[]
for i in class_names:
    count.append(len(list(data_dir_train.glob(i+'/*.jpg'))))
plt.figure(figsize=(25,10))
plt.bar(class_names,count)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# ###Fnding<br>
# 1. squamous cell carcinoma has least number of samples<br>
#
# 2.- actinic keratosis and dermatofibroma have proportionate number of classes. melanoma and pigmented benign keratosis have proprtionate number of classes

# %% [markdown]
# You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %% [markdown]
# ###To use Augmentor, the following general procedure is followed:
#
# 1.Instantiate a Pipeline object pointing to a directory containing your initial image data set.<br>
# 2.Define a number of operations to perform on this data set using your Pipeline object.<br>
# 3.Execute these operations by calling the Pipeline’s sample() method

# %%
path_to_training_dataset="/content/gdrive/MyDrive/CNN/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500)  #Adding 500 samples per class to make sure that none of the classes are sparse
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F210AC64E90>: 100%|██████████| 500/500 [00:17<00:00, 28.22 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F210B3A6050>: 100%|██████████| 500/500 [00:18<00:00, 27.47 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F210AC18FD0>: 100%|██████████| 500/500 [00:23<00:00, 21.63 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F211E22B2D0>: 100%|██████████| 500/500 [01:32<00:00,  5.43 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/nevus/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=767x576 at 0x7F210AC18950>: 100%|██████████| 500/500 [01:20<00:00,  6.21 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F211E22B2D0>: 100%|██████████| 500/500 [00:18<00:00, 27.47 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F210B3DDD90>: 100%|██████████| 500/500 [00:41<00:00, 11.98 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/squamous cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F210AC76650>: 100%|██████████| 500/500 [00:17<00:00, 27.81 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/CNN/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F210AD5D1D0>: 100%|██████████| 500/500 [00:19<00:00, 25.19 Samples/s]

# %%
#Count total number of image generated by Augmentor.
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %%
# train dataset 
train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, batch_size=32,
                                                               image_size=(180,180), label_mode='categorical',
                                                               seed=123,subset="training",
                                                               validation_split=0.2)

#label_mode is categorial, the labels are a float32 tensor of shape (batch_size, num_classes),
#representing a one-hot encoding of the class index.
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
# validation dataset 
val_ds =tf.keras.preprocessing.image_dataset_from_directory(data_dir_train,batch_size=32,
                                                            image_size=(180,180), label_mode='categorical',
                                                            seed=123,subset="validation",
                                                            validation_split=0.2)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
#tf.data.experimental.AUTOTUNE defines appropriate number of processes that are free for working.

#`Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.

#`Dataset.prefetch()` overlaps data preprocessing and model execution while training.


AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#CNN Model Architecture

#Sequential allows you to create models layer-by-layer  
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255,input_shape=(180,180,3)))   #Rescaling Layer

#First Convulation layer
model.add(layers.Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Second Convulation Layer
model.add(layers.Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Third Convulation Layer
model.add(layers.Conv2D(128,kernel_size=(3,3),activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))

#Dropout layer with 50% Fraction of the input units to drop.
model.add(layers.Dropout(0.5))

#Flatten Layer
##Keras.layers.flatten function flattens the multi-dimensional input tensors into a single dimension.
model.add(layers.Flatten())

#Dense Layer
model.add(layers.Dense(128,activation='relu'))

#Dropout layer with 25% Fraction of the input units to drop.
model.add(layers.Dropout(0.25))

#Dense Layer with softmax activation function.
#Softmax is an activation function that scales numbers/logits into probabilities.
model.add(layers.Dense(len(class_names),activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 178, 178, 32)      896
#
#  max_pooling2d_7 (MaxPooling  (None, 89, 89, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 87, 87, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_11 (Conv2D)          (None, 41, 41, 128)       73856
#
#  max_pooling2d_9 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 20, 20, 128)       0
#
#  flatten_2 (Flatten)         (None, 51200)             0
#
#  dense_2 (Dense)             (None, 128)               6553728
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 6,648,137
# Trainable params: 6,648,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
# vizualizing the model 
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
#Compile the Model

#Adam optimization: is a stochastic gradient descent method that is based on adaptive estimation of first-order and second-order moments.
#categorical_crossentropy: Used as a loss function for multi-class classification model where there are two or more output labels.

model.compile(optimizer="Adam",loss="categorical_crossentropy",metrics=["accuracy"])

#ModelCheckpoint callback is used in conjunction with training using model.fit() to save a model or weights (in a checkpoint file) at some interval,
#so the model or weights can be loaded later to continue the training from the state saved.
checkpoint = ModelCheckpoint("model.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

#Stop training when a monitored metric has stopped improving.
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,mode="auto",verbose=1)

# %%
# Train the model
epochs = 20
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/20
# 169/169 [==============================] - ETA: 0s - loss: 1.9639 - accuracy: 0.2665
# Epoch 1: val_accuracy improved from -inf to 0.42168, saving model to model.h5
# 169/169 [==============================] - 35s 74ms/step - loss: 1.9639 - accuracy: 0.2665 - val_loss: 1.5597 - val_accuracy: 0.4217
# Epoch 2/20
# 169/169 [==============================] - ETA: 0s - loss: 1.5287 - accuracy: 0.4243
# Epoch 2: val_accuracy improved from 0.42168 to 0.47216, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 1.5287 - accuracy: 0.4243 - val_loss: 1.3848 - val_accuracy: 0.4722
# Epoch 3/20
# 169/169 [==============================] - ETA: 0s - loss: 1.3835 - accuracy: 0.4789
# Epoch 3: val_accuracy improved from 0.47216 to 0.52116, saving model to model.h5
# 169/169 [==============================] - 7s 42ms/step - loss: 1.3835 - accuracy: 0.4789 - val_loss: 1.3115 - val_accuracy: 0.5212
# Epoch 4/20
# 169/169 [==============================] - ETA: 0s - loss: 1.2399 - accuracy: 0.5356
# Epoch 4: val_accuracy improved from 0.52116 to 0.53378, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 1.2399 - accuracy: 0.5356 - val_loss: 1.2030 - val_accuracy: 0.5338
# Epoch 5/20
# 169/169 [==============================] - ETA: 0s - loss: 1.1746 - accuracy: 0.5618
# Epoch 5: val_accuracy improved from 0.53378 to 0.57684, saving model to model.h5
# 169/169 [==============================] - 7s 39ms/step - loss: 1.1746 - accuracy: 0.5618 - val_loss: 1.1393 - val_accuracy: 0.5768
# Epoch 6/20
# 169/169 [==============================] - ETA: 0s - loss: 1.0648 - accuracy: 0.6087
# Epoch 6: val_accuracy improved from 0.57684 to 0.61544, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 1.0648 - accuracy: 0.6087 - val_loss: 1.0786 - val_accuracy: 0.6154
# Epoch 7/20
# 169/169 [==============================] - ETA: 0s - loss: 0.9722 - accuracy: 0.6435
# Epoch 7: val_accuracy improved from 0.61544 to 0.65924, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 0.9722 - accuracy: 0.6435 - val_loss: 0.9881 - val_accuracy: 0.6592
# Epoch 8/20
# 169/169 [==============================] - ETA: 0s - loss: 0.8915 - accuracy: 0.6754
# Epoch 8: val_accuracy did not improve from 0.65924
# 169/169 [==============================] - 7s 39ms/step - loss: 0.8915 - accuracy: 0.6754 - val_loss: 1.1448 - val_accuracy: 0.6162
# Epoch 9/20
# 169/169 [==============================] - ETA: 0s - loss: 0.8155 - accuracy: 0.6984
# Epoch 9: val_accuracy improved from 0.65924 to 0.70601, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 0.8155 - accuracy: 0.6984 - val_loss: 0.8988 - val_accuracy: 0.7060
# Epoch 10/20
# 169/169 [==============================] - ETA: 0s - loss: 0.7678 - accuracy: 0.7233
# Epoch 10: val_accuracy did not improve from 0.70601
# 169/169 [==============================] - 7s 39ms/step - loss: 0.7678 - accuracy: 0.7233 - val_loss: 0.9309 - val_accuracy: 0.6927
# Epoch 11/20
# 169/169 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.7376
# Epoch 11: val_accuracy improved from 0.70601 to 0.72532, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 0.7221 - accuracy: 0.7376 - val_loss: 0.7965 - val_accuracy: 0.7253
# Epoch 12/20
# 169/169 [==============================] - ETA: 0s - loss: 0.6100 - accuracy: 0.7780
# Epoch 12: val_accuracy improved from 0.72532 to 0.75056, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 0.6100 - accuracy: 0.7780 - val_loss: 0.8165 - val_accuracy: 0.7506
# Epoch 13/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.7795
# Epoch 13: val_accuracy did not improve from 0.75056
# 169/169 [==============================] - 7s 42ms/step - loss: 0.5839 - accuracy: 0.7795 - val_loss: 0.8365 - val_accuracy: 0.7253
# Epoch 14/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5523 - accuracy: 0.7991
# Epoch 14: val_accuracy improved from 0.75056 to 0.76318, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 0.5523 - accuracy: 0.7991 - val_loss: 0.7390 - val_accuracy: 0.7632
# Epoch 15/20
# 169/169 [==============================] - ETA: 0s - loss: 0.5585 - accuracy: 0.7966
# Epoch 15: val_accuracy did not improve from 0.76318
# 169/169 [==============================] - 7s 39ms/step - loss: 0.5585 - accuracy: 0.7966 - val_loss: 0.8038 - val_accuracy: 0.7587
# Epoch 16/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4879 - accuracy: 0.8205
# Epoch 16: val_accuracy improved from 0.76318 to 0.78396, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4879 - accuracy: 0.8205 - val_loss: 0.7573 - val_accuracy: 0.7840
# Epoch 17/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4753 - accuracy: 0.8184
# Epoch 17: val_accuracy did not improve from 0.78396
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4753 - accuracy: 0.8184 - val_loss: 0.7910 - val_accuracy: 0.7602
# Epoch 18/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4482 - accuracy: 0.8394
# Epoch 18: val_accuracy did not improve from 0.78396
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4482 - accuracy: 0.8394 - val_loss: 0.8465 - val_accuracy: 0.7736
# Epoch 19/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4392 - accuracy: 0.8468
# Epoch 19: val_accuracy improved from 0.78396 to 0.81589, saving model to model.h5
# 169/169 [==============================] - 7s 40ms/step - loss: 0.4392 - accuracy: 0.8468 - val_loss: 0.7026 - val_accuracy: 0.8159
# Epoch 20/20
# 169/169 [==============================] - ETA: 0s - loss: 0.4296 - accuracy: 0.8374
# Epoch 20: val_accuracy did not improve from 0.81589
# 169/169 [==============================] - 7s 39ms/step - loss: 0.4296 - accuracy: 0.8374 - val_loss: 0.7497 - val_accuracy: 0.7743

# %%
# Plot the training curves

epochs_range = range(earlystop.stopped_epoch+1)

plt.figure(figsize=(15, 10))
plt.subplot(1, 2, 1)

#Plot Model Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')

#Plot Model Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel(epochs_range)
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# Accuracy on training data has increased by using Augmentor library
#
# Model is still overfitting
#
# The problem of overfitting can be solved by add more layer,neurons or adding dropout layers.
#
# The Model can be further improved by tuning the hyperparamete
